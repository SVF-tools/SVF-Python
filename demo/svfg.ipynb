# %% [markdown]
# # PySVF tutorial: SVFG (Static Value-Flow Graph)
#
# ### Introduction
# This tutorial demonstrates how to use PySVF to generate SVFG (Static Value-Flow Graph) from a given source code. The SVFG is a graph representation of the program, where nodes represent program statements and edges represent the data and control dependencies between the statements. The SVFG is a powerful representation that can be used for various program analysis tasks, such as program slicing, program comprehension, and vulnerability detection.
#
# ### Prerequisites
#
# Before running this tutorial, make sure you have studied [SVFIR](svfir.ipynb) tutorial and [ICFG](icfg.ipynb) tutorial. Make sure you have installed PySVF and its dependencies.

# %%
# Install the pysvf library
# You might need to run this command in your terminal or use a Jupyter magic command
# !pip install pysvf

# Import necessary libraries
import pysvf

# Load the LLVM bitcode file
bitcode_file = "demo.ll"

# Get the pag(SVFIR) from the bitcode file, specifying that we want to build the SVFG
svfir = pysvf.getPAG(bitcode_file, build_svfg=True)

# Get the static value-flow graph (SVFG) from the pag
svfg = pysvf.getSVFG()

# Dump the SVFG to a file, the output file will be named "demo.svfg.dot"
svfg.dump("demo.svfg")
# Out:
# *********General Stats***************
# ################ (program : demo.ll)###############
# AddrsNum            21
# BBWith2Succ         1
# BBWith3Succ         0
# CallsNum            3
# ConstArrayObj       0
# ConstStructObj      0
# ConstantObj         14
# CopysNum            2
# FIObjNum            13
# FSObjNum            9
# FunctionObjs        5
# GepsNum             10
# GlobalObjs          1
# HeapObjs            1
# IndCallSites        0
# LoadsNum            3
# MaxStructSize       0
# NonPtrObj           22
# ReturnsNum          1
# StackObjs           2
# StoresNum           7
# TotalCallSite       4
# TotalFieldObjects   2
# TotalObjects        25
# TotalPTASVFStmts    22
# TotalPointers       70
# TotalSVFStmts       56
# VarArrayObj         1
# VarStructObj        0
# ----------------Time and memory stats--------------------
# LLVMIRTime          0.006
# SVFIRTime           0.001
# SymbolTableTime     0.001
# #######################################################
#
# *********PTACallGraph Stats (Andersen analysis)***************
# ################ (program : demo.ll)###############
# ----------------Numbers stats----------------------------
# CalRetPairInCycle   0
# MaxNodeInCycle      0
# NodeInCycle         0
# TotalCycle          0
# TotalEdge           4
# TotalNode           5
# #######################################################
#
# *********Andersen Pointer Analysis Stats***************
# ################ (program : demo.ll)###############
# ----------------Time and memory stats--------------------
# AvgIn/OutAddrEdge   0.25
# AvgIn/OutCopyEdge   0.4375
# AvgIn/OutEdge       0.75
# AvgIn/OutLoadEdge   0.03125
# AvgIn/OutStoreEdge  0.03125
# AvgPtsSetSize       0.2
# AvgTopLvlPtsSize    0.95
# CollapseTime        0
# CopyGepTime         0
# LoadStoreTime       0
# MemoryUsageVmrss    0
# MemoryUsageVmsize   0
# SCCDetectTime       0
# SCCMergeTime        0
# TotalTime           0
# UpdateCGTime        0
# ----------------Numbers stats----------------------------
# AddrProcessed       8
# CopyProcessed       1
# DummyFieldPtrs      2
# FieldObjs           2
# GepProcessed        10
# IndCallSites        0
# IndEdgeSolved       0
# LoadProcessed       1
# LocalVarInRecur     0
# MaxInAddrEdge       1
# MaxInCopyEdge       1
# MaxInLoadEdge       1
# MaxInStoreEdge      1
# MaxNodesInSCC       0
# MaxOutAddrEdge      1
# MaxOutCopyEdge      5
# MaxOutLoadEdge      1
# MaxOutStoreEdge     1
# MaxPtsSetSize       1
# MemObjects          25
# NodesInCycles       0
# NullPointer         0
# NumOfAddrs          8
# NumOfCGEdge         16
# NumOfCGNode         40
# NumOfCopys          4
# NumOfFieldExpand    0
# NumOfGeps           10
# NumOfLoads          1
# NumOfSCCDetect      2
# NumOfSFRs           0
# NumOfStores         1
# NumOfValidNode      32
# NumOfValidObjNode   10
# Pointers            70
# PointsToBlkPtr      0
# PointsToConstPtr    0
# SolveIterations     2
# StoreProcessed      1
# TotalCycleNum       0
# TotalObjects        25
# TotalPWCCycleNum    0
# TotalPointers       70
# #######################################################
#
# ****Persistent Points-To Cache Statistics: Andersen's analysis bitvector****
# ################ (program : demo.ll)###############
# UniquePointsToSets       11
# TotalUnions              19
# PropertyUnions           19
# UniqueUnions             0
# LookupUnions             0
# PreemptiveUnions         0
# TotalComplements         78
# PropertyComplements      78
# UniqueComplements        0
# LookupComplements        0
# PreemptiveComplements    0
# TotalIntersections       2
# PropertyIntersections    2
# UniqueIntersections      0
# LookupIntersections      0
# PreemptiveIntersections  0
# #######################################################
#
# *********Memory SSA Statistics***************
# ################ (program : demo.ll)###############
# ----------------Time and memory stats--------------------
# AverageRegSize      1
# GenMUCHITime        0
# GenRegionTime       0.001
# InsertPHITime       0
# SSARenameTime       0
# TotalMSSATime       0.001
# ----------------Numbers stats----------------------------
# BBHasMSSAPhi        0
# CSChiNode           0
# CSHasChi            0
# CSHasMu             0
# CSMuNode            0
# FunEntryChi         2
# FunHasEntryChi      1
# FunHasRetMu         2
# FunRetMu            2
# LoadHasMu           3
# LoadMuNode          3
# MSSAPhi             0
# MaxRegSize          1
# MemRegions          2
# StoreChiNode        3
# StoreHasChi         3
# #######################################################
#
# *********SVFG Statistics***************
# ################ (program : demo.ll)###############
# ----------------Time and memory stats--------------------
# ATNodeTime          0
# AvgWeight           1
# ConnDirEdgeTime     0
# ConnIndEdgeTime     0
# OptTime             0
# TLNodeTime          0
# TotalTime           0
# ----------------Numbers stats----------------------------
# ActualIn            0
# ActualOut           0
# ActualParam         13
# ActualRet           3
# Addr                21
# AvgInDegree         0
# AvgIndInDeg         1
# AvgIndOutDeg        1
# AvgOutDegree        0
# Copy                2
# DirectCallEdge      3
# DirectEdge          48
# DirectRetEdge       1
# FormalIn            2
# FormalOut           2
# FormalParam         3
# FormalRet           2
# Gep                 10
# IndCallEdge         0
# IndRetEdge          0
# IndirectEdge        8
# IndirectEdgeLabels  8
# Load                3
# MSSAPhi             0
# MaxInDegree         3
# MaxIndInDeg         1
# MaxIndOutDeg        4
# MaxOutDegree        6
# PHI                 3
# Store               7
# TotalEdge           56
# TotalNode           78
# #######################################################

# %% [markdown]
# ### Traversing the SVFG
#
# The SVFG (Sparse Value-Flow Graph) allows for the analysis of value flow between functions and supports various analyses on the program's structure.
#
# ### Basic Operations on SVFG
#
# #### SVFG Class
# - **APIs**
#   ```python
#   def getDefSVFGNode(self, val: SVFVar) -> List[VFGNode]: ...
#   # Retrieve the definition SVFG node for a given SVF variable
#
#   def getActualOUTSVFGNodes(self, cs: CallICFGNode) -> List[ActualOUTSVFGNode]: ...
#   # Retrieve the actual out SVFG nodes for a call site
#
#   def getActualINSVFGNodes(self, cs: CallICFGNode) -> List[ActualINSVFGNode]: ...
#   # Retrieve the actual in SVFG nodes for a call site
#
#   def getFormalOUTSVFGNodes(self, fun: FunObjVar) -> List[FormalOUTSVFGNode]: ...
#   # Retrieve the formal out SVFG nodes for a function
#
#   def getFormalINSVFGNodes(self, fun: FunObjVar) -> List[FormalINSVFGNode]: ...
#   # Retrieve the formal in SVFG nodes for a function
#
#   def dump(self) -> None: ...
#   # Output the SVFG
#
#   def view(self) -> None: ...
#   # Visualize the SVFG
#
#   def hasActualOUTSVFGNodes(self, cs: CallICFGNode) -> bool: ...
#   # Check for actual out SVFG nodes at a call site
#
#   def hasActualINSVFGNodes(self, cs: CallICFGNode) -> bool: ...
#   # Check for actual in SVFG nodes at a call site
#
#   def hasFormalOUTSVFGNodes(self, fun: FunObjVar) -> bool: ...
#   # Check for formal out SVFG nodes for a function
#
#   def hasFormalINSVFGNodes(self, fun: FunObjVar) -> bool: ...
#   # Check for formal in SVFG nodes for a function
#   ```
#
# #### SVFGNode Class
# - **APIs**
#   ```python
#   def toString(self) -> str: ...
#   # Get the string representation of the SVFG node
#
#   def __str__(self) -> str: ...
#   # Get the string representation of the SVFG node
#
#   def getId(self) -> int: ...
#   # Retrieve the ID of the SVFG node
#
#   def getICFGNode(self) -> ICFGNode: ...
#   # Retrieve the ICFG node associated with the SVFG node
#
#   def getDefSVFVars(self) -> List[SVFVar]: ...
#   # Retrieve the defined SVF variables
#
#   def getOutEdges(self) -> List[VFGEdge]: ...
#   # Retrieve the outgoing edges
#
#   def getInEdges(self) -> List[VFGEdge]: ...
#   # Retrieve the incoming edges
#
#   def isStmtVFGNode(self) -> bool: ...
#   # Check if the node is a statement VFG node
#
#   def isPhiVFGNode(self) -> bool: ...
#   # Check if the node is a PHI VFG node
#
#   def isArgumentVFGNode(self) -> bool: ...
#   # Check if the node is an argument VFG node
#
#   def isCmpVFGNode(self) -> bool: ...
#   # Check if the node is a compare VFG node
#
#   def isBinaryOpVFGNode(self) -> bool: ...
#   # Check if the node is a binary operation VFG node
#
#   def isUnaryOpVFGNode(self) -> bool: ...
#   # Check if the node is a unary operation VFG node
#
#   def isBranchVFGNode(self) -> bool: ...
#   # Check if the node is a branch VFG node
#
#   def asStmtVFGNode(self) -> StmtVFGNode: ...
#   # Downcast to StmtVFGNode
#
#   def asPhiVFGNode(self) -> PHIVFGNode: ...
#   # Downcast to PHIVFGNode
#
#   def asArgumentVFGNode(self) -> ArgumentVFGNode: ...
#   # Downcast to ArgumentVFGNode
#
#   def asCmpVFGNode(self) -> CmpVFGNode: ...
#   # Downcast to CmpVFGNode
#
#   def asBinaryOpVFGNode(self) -> BinaryOPVFGNode: ...
#   # Downcast to BinaryOPVFGNode
#
#   def asUnaryOpVFGNode(self) -> UnaryOPVFGNode: ...
#   # Downcast to UnaryOPVFGNode
#
#   def asBranchVFGNode(self) -> BranchVFGNode: ...
#   # Downcast to BranchVFGNode
#
#   def getValue(self) -> SVFVar: ...
#   # Retrieve the value of the SVFG node
#   ```
#
# #### SVFGEdge Class
# - **APIs**
#   ```python
#   def toString(self) -> str: ...
#   # Get the string representation of the SVFG edge
#
#   def __str__(self) -> str: ...
#   # Get the string representation of the SVFG edge
#
#   def isDirectVFGEdge(self) -> bool: ...
#   # Check if the edge is a direct VFG edge
#
#   def isIndirectVFGEdge(self) -> bool: ...
#   # Check if the edge is an indirect VFG edge
#
#   def isCallVFGEdge(self) -> bool: ...
#   # Check if the edge is a call VFG edge
#
#   def isRetVFGEdge(self) -> bool: ...
#   # Check if the edge is a return VFG edge
#
#   def isCallDirectVFGEdge(self) -> bool: ...
#   # Check if the edge is a call direct VFG edge
#
#   def isRetDirectVFGEdge(self) -> bool: ...
#   # Check if the edge is a return direct VFG edge
#
#   def isCallIndirectVFGEdge(self) -> bool: ...
#   # Check if the edge is a call indirect VFG edge
#
#   def isRetIndirectVFGEdge(self) -> bool: ...
#   # Check if the edge is a return indirect VFG edge
#
#   def isIntraVFGEdge(self) -> bool: ...
#   # Check if the edge is an intra VFG edge
#
#   def isThreadMHPIndirectVFGEdge(self) -> bool: ...
#   # Check if the edge is a thread MHP indirect VFG edge
#
#   def getSrc(self) -> VFGNode: ...
#   # Retrieve the source node
#
#   def getDst(self) -> VFGNode: ...
#   # Retrieve the destination node
#
#   def asDirectSVFGEdge(self) -> DirectSVFGEdge: ...
#   # Downcast to DirectSVFGEdge
#
#   def asIndirectSVFGEdge(self) -> IndirectSVFGEdge: ...
#   # Downcast to IndirectSVFGEdge
#   ```
#
# When printing all nodes in the SVFG, be aware that the output may be extensive for large programs.

# %%
for node in svfg.getNodes():
    print(node)
# Out:
# NullPtrVFGNode ID: 0 PAGNode ID: 0
#
# AddrVFGNode ID: 1 AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrVFGNode ID: 2 AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrVFGNode ID: 3 AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrVFGNode ID: 4 AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrVFGNode ID: 5 AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# AddrVFGNode ID: 6 AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrVFGNode ID: 7 AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrVFGNode ID: 8 AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrVFGNode ID: 9 AddrStmt: [Var34 <-- Var35]
# ValVar ID: 34
#    %0 = alloca i8, i64 8, align 8
# AddrVFGNode ID: 10 AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrVFGNode ID: 11 AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrVFGNode ID: 12 AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrVFGNode ID: 13 AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrVFGNode ID: 14 AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrVFGNode ID: 15 AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrVFGNode ID: 16 AddrStmt: [Var57 <-- Var58]
# ValVar ID: 57
#    %3 = alloca i8, i64 8, align 8
# AddrVFGNode ID: 17 AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrVFGNode ID: 18 AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrVFGNode ID: 19 AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrVFGNode ID: 20 AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrVFGNode ID: 21 AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# CopyVFGNode ID: 22 CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# CopyVFGNode ID: 23 CopyStmt: [Var66 <-- Var57]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# GepVFGNode ID: 24 GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepVFGNode ID: 25 GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepVFGNode ID: 26 GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepVFGNode ID: 27 GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepVFGNode ID: 28 GepStmt: [Var38 <-- Var34]
# ValVar ID: 38
#    %arrayidx = getelementptr inbounds i32, ptr %0, i64 0
# GepVFGNode ID: 29 GepStmt: [Var44 <-- Var34]
# ValVar ID: 44
#    %arrayidx1 = getelementptr inbounds i32, ptr %0, i64 1
# GepVFGNode ID: 30 GepStmt: [Var50 <-- Var34]
# ValVar ID: 50
#    %arrayidx2 = getelementptr inbounds i32, ptr %0, i64 0
# GepVFGNode ID: 31 GepStmt: [Var52 <-- Var34]
# ValVar ID: 52
#    %arrayidx3 = getelementptr inbounds i32, ptr %0, i64 1
# GepVFGNode ID: 32 GepStmt: [Var91 <-- Var34]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# GepVFGNode ID: 33 GepStmt: [Var90 <-- Var57]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# LoadVFGNode ID: 34 LoadStmt: [Var51 <-- Var50]
# ValVar ID: 51
#    %1 = load i32, ptr %arrayidx2, align 4
# LoadVFGNode ID: 35 LoadStmt: [Var53 <-- Var52]
# ValVar ID: 53
#    %2 = load i32, ptr %arrayidx3, align 4
# LoadVFGNode ID: 36 LoadStmt: [Var92 <-- Var91]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# StoreVFGNode ID: 37 StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# StoreVFGNode ID: 38 StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# StoreVFGNode ID: 39 StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# StoreVFGNode ID: 40 StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# StoreVFGNode ID: 41 StoreStmt: [Var38 <-- Var42]
# ValVar ID: 41
#    store i32 5, ptr %arrayidx, align 4
# StoreVFGNode ID: 42 StoreStmt: [Var44 <-- Var48]
# ValVar ID: 47
#    store i32 3, ptr %arrayidx1, align 4
# StoreVFGNode ID: 43 StoreStmt: [Var90 <-- Var92]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# ActualParmVFGNode ID: 44 CS[CallICFGNode: ]GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# ActualParmVFGNode ID: 45 CS[CallICFGNode: ]ValVar ID: 54
#    %call = call i32 @add_or_sub(i32 noundef %1, i32 noundef %2, i32 noundef 1)
# ActualParmVFGNode ID: 46 CS[CallICFGNode: ]ValVar ID: 57
#    %3 = alloca i8, i64 8, align 8
# ActualParmVFGNode ID: 47 CS[CallICFGNode: ]ValVar ID: 34
#    %0 = alloca i8, i64 8, align 8
# ActualParmVFGNode ID: 48 CS[CallICFGNode: ]ConstIntValVar ID: 36
#  i64 8 { constant data }
# ActualParmVFGNode ID: 49 CS[CallICFGNode: ]ValVar ID: 59
#    %4 = call i64 @llvm.objectsize.i64.p0(ptr %3, i1 false, i1 true, i1 false)
# ActualParmVFGNode ID: 50 CS[CallICFGNode: ]ValVar ID: 57
#    %3 = alloca i8, i64 8, align 8
# ActualParmVFGNode ID: 51 CS[CallICFGNode: ]ConstIntValVar ID: 60
#  i1 false { constant data }
# ActualParmVFGNode ID: 52 CS[CallICFGNode: ]ConstIntValVar ID: 62
#  i1 true { constant data }
# ActualParmVFGNode ID: 53 CS[CallICFGNode: ]ConstIntValVar ID: 60
#  i1 false { constant data }
# ActualParmVFGNode ID: 54 CS[CallICFGNode: ]ValVar ID: 51
#    %1 = load i32, ptr %arrayidx2, align 4
# ActualParmVFGNode ID: 55 CS[CallICFGNode: ]ValVar ID: 53
#    %2 = load i32, ptr %arrayidx3, align 4
# ActualParmVFGNode ID: 56 CS[CallICFGNode: ]ConstIntValVar ID: 55
#  i32 1 { constant data }
# ActualRetVFGNode ID: 57 CS[CallICFGNode: ]ValVar ID: 69
#    %call5 = call i32 (ptr, ...) @printf(ptr noundef @.str, i32 noundef %call)
# ActualRetVFGNode ID: 58 CS[CallICFGNode: ]ValVar ID: 59
#    %4 = call i64 @llvm.objectsize.i64.p0(ptr %3, i1 false, i1 true, i1 false)
# ActualRetVFGNode ID: 59 CS[CallICFGNode: ]ValVar ID: 54
#    %call = call i32 @add_or_sub(i32 noundef %1, i32 noundef %2, i32 noundef 1)
# FormalParmVFGNode ID: 60 Fun[add_or_sub]ArgValVar ID: 17
#  i32 %a { 0th arg add_or_sub  }
# FormalParmVFGNode ID: 61 Fun[add_or_sub]ArgValVar ID: 18
#  i32 %b { 1st arg add_or_sub  }
# FormalParmVFGNode ID: 62 Fun[add_or_sub]ArgValVar ID: 19
#  i32 %flag { 2nd arg add_or_sub  }
# FormalRetVFGNode ID: 63 Fun[main]RetValPN ID: 33 unique return node for function main
# FormalRetVFGNode ID: 64 Fun[add_or_sub]RetValPN ID: 16 unique return node for function add_or_sub
# IntraPHIVFGNode ID: 65 PAGNode: [33 = PHI(21, )]	  ; Function Attrs: noinline nounwind ssp uwtable(sync)
# define i32 @main() #0 {
# entry:
#   %0 = alloca i8, i64 8, align 8
#   %arrayidx = getelementptr inbounds i32, ptr %0, i64 0
#   store i32 5, ptr %arrayidx, align 4
#   %arrayidx1 = getelementptr inbounds i32, ptr %0, i64 1
#   store i32 3, ptr %arrayidx1, align 4
#   %arrayidx2 = getelementptr inbounds i32, ptr %0, i64 0
#   %1 = load i32, ptr %arrayidx2, align 4
#   %arrayidx3 = getelementptr inbounds i32, ptr %0, i64 1
#   %2 = load i32, ptr %arrayidx3, align 4
#   %call = call i32 @add_or_sub(i32 noundef %1, i32 noundef %2, i32 noundef 1)
#   %3 = alloca i8, i64 8, align 8
#   %4 = call i64 @llvm.objectsize.i64.p0(ptr %3, i1 false, i1 true, i1 false)
#   %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
#   %call5 = call i32 (ptr, ...) @printf(ptr noundef @.str, i32 noundef %call)
#   ret i32 0
# }
#
# IntraPHIVFGNode ID: 66 PAGNode: [29 = PHI(27, 24, )]	    %result.0 = phi i32 [ %add, %if.then ], [ %sub, %if.else ]
# IntraPHIVFGNode ID: 67 PAGNode: [16 = PHI(29, )]	  ; Function Attrs: noinline nounwind ssp uwtable(sync)
# define i32 @add_or_sub(i32 noundef %a, i32 noundef %b, i32 noundef %flag) #0 {
# entry:
#   %tobool = icmp ne i32 %flag, 0
#   br i1 %tobool, label %if.then, label %if.else
#
# if.then:                                          ; preds = %entry
#   %add = add nsw i32 %a, %b
#   br label %if.end
#
# if.else:                                          ; preds = %entry
#   %sub = sub nsw i32 %a, %b
#   br label %if.end
#
# if.end:                                           ; preds = %if.else, %if.then
#   %result.0 = phi i32 [ %add, %if.then ], [ %sub, %if.else ]
#   ret i32 %result.0
# }
#
# BinaryOPVFGNode ID: 68 PAGEdge: [24 = Binary(18, 17, )]	    %add = add nsw i32 %a, %b
# BinaryOPVFGNode ID: 69 PAGEdge: [27 = Binary(18, 17, )]	    %sub = sub nsw i32 %a, %b
# BranchVFGNode ID: 70 PAGEdge: [BranchStmt: [ Unconditional branch]
# Successor 0 ICFGNode11
# ValVar ID: 25
#    br label %if.end
# BranchVFGNode ID: 71 PAGEdge: [BranchStmt: [ Unconditional branch]
# Successor 0 ICFGNode11
# ValVar ID: 28
#    br label %if.end
# BranchVFGNode ID: 72 PAGEdge: [BranchStmt: [Condition Var20]
# Successor 0 ICFGNode7   Successor 1 ICFGNode8
# ValVar ID: 23
#    br i1 %tobool, label %if.then, label %if.else
# CmpVFGNode ID: 73 PAGEdge: [20 = cmp(21, 19, )]
#     %tobool = icmp ne i32 %flag, 0
# FormalINSVFGNode ID: 74 {fun: main}4V_1 = ENCHI(MR_4V_1)
# pts{94 }
#
# FormalINSVFGNode ID: 75 {fun: main}2V_1 = ENCHI(MR_2V_1)
# pts{93 }
#
# FormalOUTSVFGNode ID: 76 {fun: main}RETMU(4V_3)
# pts{94 }
#
# FormalOUTSVFGNode ID: 77 {fun: main}RETMU(2V_2)
# pts{93 }

# %% [markdown]
# From the output above, we can see the list of SVFG nodes in the program, each representing a program statement. We can also traverse the edges in the SVFG to analyze the data and control dependencies between the statements.
#
# #### Visualizing the SVFG
#
# To visualize the SVFG, we can use the `graphviz` library to generate a graphical representation of the control flow between functions. The `dump` function of the SVFG class generates a DOT file that can be rendered using Graphviz.
#
# ![Alt text](svfgdot.png)
#
# ### Exploring the SVFG
#
# We can explore the SVFG to analyze the data and control dependencies between the statements in the program. We can use the APIs provided by the SVFG class to get the definition SVFG node for a given SVF variable, get the actual out SVFG nodes for a call site, get the formal out SVFG nodes for a function, and so on.
#
# #### SVFGNode
#
# We can use the APIs provided by the SVFGNode class to get the ID of the SVFG node, get the ICFG node associated with the SVFG node, get the defined SVF variables, get the outgoing edges, get the incoming edges, and so on.
#
# ```
# classDiagram
#     VFGNode <|-- StmtVFGNode
#     VFGNode <|-- PHIVFGNode
#     VFGNode <|-- ArgumentVFGNode
#     VFGNode <|-- CmpVFGNode
#     VFGNode <|-- BinaryOPVFGNode
#     VFGNode <|-- UnaryOPVFGNode
#     VFGNode <|-- BranchVFGNode
#     VFGNode <|-- MRSVFGNode
#     VFGNode <|-- DummyVersionPropSVFGNode
#
#     StmtVFGNode <|-- LoadVFGNode
#     StmtVFGNode <|-- StoreVFGNode
#     StmtVFGNode <|-- CopyVFGNode
#     StmtVFGNode <|-- GepVFGNode
#     StmtVFGNode <|-- AddrVFGNode
#
#     PHIVFGNode <|-- IntraPHIVFGNode
#     PHIVFGNode <|-- InterPHIVFGNode
#
#     ArgumentVFGNode <|-- ActualParmVFGNode
#     ArgumentVFGNode <|-- FormalParmVFGNode
#     ArgumentVFGNode <|-- ActualRetVFGNode
#     ArgumentVFGNode <|-- FormalRetVFGNode
#
#     MRSVFGNode <|-- FormalINSVFGNode
#     MRSVFGNode <|-- FormalOUTSVFGNode
#     MRSVFGNode <|-- ActualINSVFGNode
#     MRSVFGNode <|-- ActualOUTSVFGNode
#     MRSVFGNode <|-- MSSAPHISVFGNode
#
#     MSSAPHISVFGNode <|-- IntraMSSAPHISVFGNode
#     MSSAPHISVFGNode <|-- InterMSSAPHISVFGNode
# ```
# #### SVFGEdge
# ```
# classDiagram
#     VFGEdge <|-- DirectSVFGEdge
#     VFGEdge <|-- IndirectSVFGEdge
#
#     DirectSVFGEdge <|-- IntraDirSVFGEdge
#     DirectSVFGEdge <|-- CallDirSVFGEdge
#     DirectSVFGEdge <|-- RetDirSVFGEdge
#
#     IndirectSVFGEdge <|-- IntraIndSVFGEdge
#     IndirectSVFGEdge <|-- CallIndSVFGEdge
#     IndirectSVFGEdge <|-- RetIndSVFGEdge
#     IndirectSVFGEdge <|-- ThreadMHPIndSVFGEdge
# ```

# %%
for node in svfg.getNodes():
    if isinstance(node, pysvf.StmtVFGNode):
        stmt_vfg_node = node.asStmtVFGNode()
        print("ID: {}, SVFGNode: {}, ICFGNode: {}, SVFVar: {}".format(node.getId(), node, node.getId(), stmt_vfg_node.getValue()))
    # for other types of nodes, you can use the corresponding class name
# Out:
# ID: 1, SVFGNode: AddrVFGNode ID: 1 AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: ConstIntValVar ID: 5
#  i8 37 { constant data }
# ID: 2, SVFGNode: AddrVFGNode ID: 2 AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: ConstIntValVar ID: 7
#  i8 100 { constant data }
# ID: 3, SVFGNode: AddrVFGNode ID: 3 AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: ConstIntValVar ID: 9
#  i8 10 { constant data }
# ID: 4, SVFGNode: AddrVFGNode ID: 4 AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: ConstIntValVar ID: 11
#  i8 0 { constant data }
# ID: 5, SVFGNode: AddrVFGNode ID: 5 AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# ID: 6, SVFGNode: AddrVFGNode ID: 6 AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: FunValVar ID: 14
# add_or_sub
# ID: 7, SVFGNode: AddrVFGNode ID: 7 AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: ConstIntValVar ID: 21
#  i32 0 { constant data }
# ID: 8, SVFGNode: AddrVFGNode ID: 8 AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: FunValVar ID: 31
# main
# ID: 9, SVFGNode: AddrVFGNode ID: 9 AddrStmt: [Var34 <-- Var35]
# ValVar ID: 34
#    %0 = alloca i8, i64 8, align 8 , ICFGNode: IntraICFGNode13 {fun: main}
# AddrStmt: [Var34 <-- Var35]
# ValVar ID: 34
#    %0 = alloca i8, i64 8, align 8
# , SVFVar: ValVar ID: 34
#    %0 = alloca i8, i64 8, align 8
# ID: 10, SVFGNode: AddrVFGNode ID: 10 AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: ConstIntValVar ID: 36
#  i64 8 { constant data }
# ID: 11, SVFGNode: AddrVFGNode ID: 11 AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: ConstIntValVar ID: 39
#  i64 0 { constant data }
# ID: 12, SVFGNode: AddrVFGNode ID: 12 AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: ConstIntValVar ID: 42
#  i32 5 { constant data }
# ID: 13, SVFGNode: AddrVFGNode ID: 13 AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: ConstIntValVar ID: 45
#  i64 1 { constant data }
# ID: 14, SVFGNode: AddrVFGNode ID: 14 AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: ConstIntValVar ID: 48
#  i32 3 { constant data }
# ID: 15, SVFGNode: AddrVFGNode ID: 15 AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: ConstIntValVar ID: 55
#  i32 1 { constant data }
# ID: 16, SVFGNode: AddrVFGNode ID: 16 AddrStmt: [Var57 <-- Var58]
# ValVar ID: 57
#    %3 = alloca i8, i64 8, align 8 , ICFGNode: IntraICFGNode24 {fun: main}
# AddrStmt: [Var57 <-- Var58]
# ValVar ID: 57
#    %3 = alloca i8, i64 8, align 8
# , SVFVar: ValVar ID: 57
#    %3 = alloca i8, i64 8, align 8
# ID: 17, SVFGNode: AddrVFGNode ID: 17 AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: ConstIntValVar ID: 60
#  i1 false { constant data }
# ID: 18, SVFGNode: AddrVFGNode ID: 18 AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: ConstIntValVar ID: 62
#  i1 true { constant data }
# ID: 19, SVFGNode: AddrVFGNode ID: 19 AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: FunValVar ID: 64
# llvm.objectsize.i64.p0
# ID: 20, SVFGNode: AddrVFGNode ID: 20 AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: FunValVar ID: 67
# __memcpy_chk
# ID: 21, SVFGNode: AddrVFGNode ID: 21 AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: FunValVar ID: 70
# printf
# ID: 22, SVFGNode: CopyVFGNode ID: 22 CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ...
# GepStmt: [Var50 <-- Var34]
# ValVar ID: 50
#    %arrayidx2 = getelementptr inbounds i32, ptr %0, i64 0
# , SVFVar: ValVar ID: 50
#    %arrayidx2 = getelementptr inbounds i32, ptr %0, i64 0
# ID: 31, SVFGNode: GepVFGNode ID: 31 GepStmt: [Var52 <-- Var34]
# ValVar ID: 52
#    %arrayidx3 = getelementptr inbounds i32, ptr %0, i64 1 , ICFGNode: IntraICFGNode20 {fun: main}
# GepStmt: [Var52 <-- Var34]
# ValVar ID: 52
#    %arrayidx3 = getelementptr inbounds i32, ptr %0, i64 1
# , SVFVar: ValVar ID: 52
#    %arrayidx3 = getelementptr inbounds i32, ptr %0, i64 1
# ID: 32, SVFGNode: GepVFGNode ID: 32 GepStmt: [Var91 <-- Var34]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4 , ICFGNode: CallICFGNode27 {fun: main}
# GepStmt: [Var90 <-- Var57]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# GepStmt: [Var91 <-- Var34]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# LoadStmt: [Var92 <-- Var91]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# StoreStmt: [Var90 <-- Var92]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# CopyStmt: [Var66 <-- Var57]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# , SVFVar: ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# ID: 33, SVFGNode: GepVFGNode ID: 33 GepStmt: [Var90 <-- Var57]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4 , ICFGNode: CallICFGNode27 {fun: main}
# GepStmt: [Var90 <-- Var57]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# GepStmt: [Var91 <-- Var34]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# LoadStmt: [Var92 <-- Var91]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# StoreStmt: [Var90 <-- Var92]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# CopyStmt: [Var66 <-- Var57]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# , SVFVar: ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# ID: 34, SVFGNode: LoadVFGNode ID: 34 LoadStmt: [Var51 <-- Var50]
# ValVar ID: 51
#    %1 = load i32, ptr %arrayidx2, align 4 , ICFGNode: IntraICFGNode19 {fun: main}
# LoadStmt: [Var51 <-- Var50]
# ValVar ID: 51
#    %1 = load i32, ptr %arrayidx2, align 4
# , SVFVar: ValVar ID: 51
#    %1 = load i32, ptr %arrayidx2, align 4
# ID: 35, SVFGNode: LoadVFGNode ID: 35 LoadStmt: [Var53 <-- Var52]
# ValVar ID: 53
#    %2 = load i32, ptr %arrayidx3, align 4 , ICFGNode: IntraICFGNode21 {fun: main}
# LoadStmt: [Var53 <-- Var52]
# ValVar ID: 53
#    %2 = load i32, ptr %arrayidx3, align 4
# , SVFVar: ValVar ID: 53
#    %2 = load i32, ptr %arrayidx3, align 4
# ID: 36, SVFGNode: LoadVFGNode ID: 36 LoadStmt: [Var92 <-- Var91]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4 , ICFGNode: CallICFGNode27 {fun: main}
# GepStmt: [Var90 <-- Var57]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# GepStmt: [Var91 <-- Var34]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# LoadStmt: [Var92 <-- Var91]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# StoreStmt: [Var90 <-- Var92]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# CopyStmt: [Var66 <-- Var57]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# , SVFVar: ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# ID: 37, SVFGNode: StoreVFGNode ID: 37 StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: ConstIntValVar ID: 5
#  i8 37 { constant data }
# ID: 38, SVFGNode: StoreVFGNode ID: 38 StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: ConstIntValVar ID: 7
#  i8 100 { constant data }
# ID: 39, SVFGNode: StoreVFGNode ID: 39 StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: ConstIntValVar ID: 9
#  i8 10 { constant data }
# ID: 40, SVFGNode: StoreVFGNode ID: 40 StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }, ICFGNode: GlobalICFGNode0
# CopyStmt: [Var1 <-- Var0]
# ConstNullPtrValVar ID: 0
#  ptr null { constant data }
# AddrStmt: [Var11 <-- Var12]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var7 <-- Var8]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# AddrStmt: [Var55 <-- Var56]
# ConstIntValVar ID: 55
#  i32 1 { constant data }
# AddrStmt: [Var39 <-- Var40]
# ConstIntValVar ID: 39
#  i64 0 { constant data }
# AddrStmt: [Var36 <-- Var37]
# ConstIntValVar ID: 36
#  i64 8 { constant data }
# AddrStmt: [Var60 <-- Var61]
# ConstIntValVar ID: 60
#  i1 false { constant data }
# AddrStmt: [Var21 <-- Var22]
# ConstIntValVar ID: 21
#  i32 0 { constant data }
# AddrStmt: [Var9 <-- Var10]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# AddrStmt: [Var42 <-- Var43]
# ConstIntValVar ID: 42
#  i32 5 { constant data }
# AddrStmt: [Var45 <-- Var46]
# ConstIntValVar ID: 45
#  i64 1 { constant data }
# AddrStmt: [Var48 <-- Var49]
# ConstIntValVar ID: 48
#  i32 3 { constant data }
# AddrStmt: [Var62 <-- Var63]
# ConstIntValVar ID: 62
#  i1 true { constant data }
# AddrStmt: [Var5 <-- Var6]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# AddrStmt: [Var4 <-- Var13]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# GepStmt: [Var86 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var86 <-- Var5]
# ConstIntValVar ID: 5
#  i8 37 { constant data }
# GepStmt: [Var87 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var87 <-- Var7]
# ConstIntValVar ID: 7
#  i8 100 { constant data }
# GepStmt: [Var88 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var88 <-- Var9]
# ConstIntValVar ID: 9
#  i8 10 { constant data }
# GepStmt: [Var89 <-- Var4]
# GlobalValVar ID: 4
#  @.str = private unnamed_addr constant [4 x i8] c"%d\0A\00", align 1 { Glob  }
# StoreStmt: [Var89 <-- Var11]
# ConstIntValVar ID: 11
#  i8 0 { constant data }
# AddrStmt: [Var14 <-- Var15]
# FunValVar ID: 14
# add_or_sub
# AddrStmt: [Var31 <-- Var32]
# FunValVar ID: 31
# main
# AddrStmt: [Var67 <-- Var68]
# FunValVar ID: 67
# __memcpy_chk
# AddrStmt: [Var64 <-- Var65]
# FunValVar ID: 64
# llvm.objectsize.i64.p0
# AddrStmt: [Var70 <-- Var71]
# FunValVar ID: 70
# printf
# , SVFVar: ConstIntValVar ID: 11
#  i8 0 { constant data }
# ID: 41, SVFGNode: StoreVFGNode ID: 41 StoreStmt: [Var38 <-- Var42]
# ValVar ID: 41
#    store i32 5, ptr %arrayidx, align 4 , ICFGNode: IntraICFGNode15 {fun: main}
# StoreStmt: [Var38 <-- Var42]
# ValVar ID: 41
#    store i32 5, ptr %arrayidx, align 4
# , SVFVar: ValVar ID: 41
#    store i32 5, ptr %arrayidx, align 4
# ID: 42, SVFGNode: StoreVFGNode ID: 42 StoreStmt: [Var44 <-- Var48]
# ValVar ID: 47
#    store i32 3, ptr %arrayidx1, align 4 , ICFGNode: IntraICFGNode17 {fun: main}
# StoreStmt: [Var44 <-- Var48]
# ValVar ID: 47
#    store i32 3, ptr %arrayidx1, align 4
# , SVFVar: ValVar ID: 47
#    store i32 3, ptr %arrayidx1, align 4
# ID: 43, SVFGNode: StoreVFGNode ID: 43 StoreStmt: [Var90 <-- Var92]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4 , ICFGNode: CallICFGNode27 {fun: main}
# GepStmt: [Var90 <-- Var57]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# GepStmt: [Var91 <-- Var34]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# LoadStmt: [Var92 <-- Var91]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# StoreStmt: [Var90 <-- Var92]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# CopyStmt: [Var66 <-- Var57]
# ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4
# , SVFVar: ValVar ID: 66
#    %call4 = call ptr @__memcpy_chk(ptr noundef %3, ptr noundef %0, i64 noundef 8, i64 noundef %4) #4

# %% [markdown]
# ### Connect with SVFVar and ICFGNode
#
# The SVFG nodes are connected with SVFVar and ICFGNode. We can use the APIs provided by the SVFGNode class to get the SVFVar and ICFGNode associated with the SVFG node.
#
# For example, we can see ID: 66 as follows.
#
# ```
# IntraPHIVFGNode ID: 66 PAGNode: [29 = PHI(27, 24, )]	    %result.0 = phi i32 [ %add, %if.then ], [ %sub, %if.else ]
# ```
#
# We know it is a PHI node, and the corresponding PAGNode is `PHI(27, 24, )`, and the ICFGNode should have a PHI SVFStmt.

# %%
node = svfg.getGNode(66)
if isinstance(node, pysvf.PHIVFGNode):
    phi_svfg_node = node.asPhiVFGNode()
    svf_var = phi_svfg_node.getValue()
    icfg_node = phi_svfg_node.getICFGNode()
    print("SVFGNode: {}, corresponding ICFGNode: {}, corresponding SVFVar: {}".format(node, icfg_node, svf_var))
# Out:
# SVFGNode: IntraPHIVFGNode ID: 66 PAGNode: [29 = PHI(27, 24, )]	    %result.0 = phi i32 [ %add, %if.then ], [ %sub, %if.else ] , corresponding ICFGNode: IntraICFGNode11 {fun: add_or_sub}
# PhiStmt: [Var29 <-- ([Var24, ICFGNode9],[Var27, ICFGNode10],)]
# ValVar ID: 29
#    %result.0 = phi i32 [ %add, %if.then ], [ %sub, %if.else ]
# , corresponding SVFVar: ValVar ID: 29
#    %result.0 = phi i32 [ %add, %if.then ], [ %sub, %if.else ]

# %% [markdown]
# From the output above, we can see the SVFG node with ID 66 is a PHI node, and the corresponding PAGNode is `ValVar ID: 29
#    %result.0 = phi i32 [ %add, %if.then ], [ %sub, %if.else ]`. The ICFGNode associated with the SVFG node is `IntraICFGNode11 {fun: add_or_sub}
# PhiStmt: [Var29 <-- ([Var24, ICFGNode9],[Var27, ICFGNode10],)]
# ValVar ID: 29
#    %result.0 = phi i32 [ %add, %if.then ], [ %sub, %if.else ] `. Although they are different types of nodes and ids, they are connected through these apis.
#
# ### Summary
# This tutorial demonstrates how to use PySVF to generate SVFG from a given source code. We can use the SVFG to analyze the data and control dependencies between the statements in the program, especially for its connections to SVFVar and ICFGNode. The SVFG is a powerful representation that can be used for various program analysis tasks, such as program slicing, program comprehension, and vulnerability detection.
