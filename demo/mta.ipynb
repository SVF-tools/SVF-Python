# %%
import pysvf

# %%
# Load the LLVM bitcode file
bitcode_file = "demo_mta.ll"

# Get the pag(SVFIR) from the bitcode file
svfir = pysvf.get_svfir(bitcode_file)

# %%
pysvf.run_pta(pysvf.Steensgaard_WPA)
# Out:
# *********General Stats***************
# ################ (program : demo_mta.ll)###############
# AddrsNum            12
# BBWith2Succ         0
# BBWith3Succ         0
# CallsNum            0
# ConstArrayObj       0
# ConstStructObj      0
# ConstantObj         2
# CopysNum            1
# FIObjNum            9
# FSObjNum            4
# FunctionObjs        6
# GepsNum             0
# GlobalObjs          0
# HeapObjs            1
# IndCallSites        0
# LoadsNum            2
# MaxStructSize       0
# NonPtrObj           9
# ReturnsNum          0
# StackObjs           4
# StoresNum           2
# TotalCallSite       4
# TotalFieldObjects   0
# TotalObjects        14
# TotalPTASVFStmts    21
# TotalPointers       46
# TotalSVFStmts       22
# VarArrayObj         0
# VarStructObj        0
# ----------------Time and memory stats--------------------
# LLVMIRTime          0.01
# SVFIRTime           0
# SymbolTableTime     0.001
# #######################################################
#
# *********PTACallGraph Stats (Andersen analysis)***************
# ################ (program : demo_mta.ll)###############
# ----------------Numbers stats----------------------------
# CalRetPairInCycle   0
# MaxNodeInCycle      0
# NodeInCycle         0
# TotalCycle          0
# TotalEdge           6
# TotalNode           6
# #######################################################
#
# *********Andersen Pointer Analysis Stats***************
# ################ (program : demo_mta.ll)###############
# ----------------Time and memory stats--------------------
# AvgIn/OutAddrEdge   0.375
# AvgIn/OutCopyEdge   0.15625
# AvgIn/OutEdge       0.65625
# AvgIn/OutLoadEdge   0.0625
# AvgIn/OutStoreEdge  0.0625
# AvgPtsSetSize       0.2
# AvgTopLvlPtsSize    0.588235
# CollapseTime        0
# CopyGepTime         0
# LoadStoreTime       0
# MemoryUsageVmrss    0
# MemoryUsageVmsize   0
# SCCDetectTime       0
# SCCMergeTime        0
# TotalTime           0
# UpdateCGTime        0
# ----------------Numbers stats----------------------------
# AddrProcessed       12
# CopyProcessed       0
# DummyFieldPtrs      0
# FieldObjs           0
# GepProcessed        0
# IndCallSites        0
# IndEdgeSolved       0
# LoadProcessed       0
# LocalVarInRecur     0
# MaxInAddrEdge       1
# MaxInCopyEdge       1
# MaxInLoadEdge       1
# MaxInStoreEdge      1
# MaxNodesInSCC       0
# MaxOutAddrEdge      1
# MaxOutCopyEdge      5
# MaxOutLoadEdge      1
# MaxOutStoreEdge     1
# MaxPtsSetSize       1
# MemObjects          14
# NodesInCycles       0
# NullPointer         0
# NumOfAddrs          12
# NumOfCGEdge         9
# NumOfCGNode         40
# NumOfCopys          5
# NumOfFieldExpand    0
# NumOfGeps           0
# NumOfLoads          2
# NumOfSCCDetect      0
# NumOfSFRs           0
# NumOfStores         2
# NumOfValidNode      32
# NumOfValidObjNode   12
# Pointers            46
# PointsToBlkPtr      0
# PointsToConstPtr    0
# SolveIterations     1
# StoreProcessed      0
# TotalCycleNum       0
# TotalObjects        14
# TotalPWCCycleNum    0
# TotalPointers       46
# #######################################################
#
# ****Persistent Points-To Cache Statistics: Andersen's analysis bitvector****
# ################ (program : demo_mta.ll)###############
# UniquePointsToSets       13
# TotalUnions              21
# PropertyUnions           21
# UniqueUnions             0
# LookupUnions             0
# PreemptiveUnions         0
# TotalComplements         0
# PropertyComplements      0
# UniqueComplements        0
# LookupComplements        0
# PreemptiveComplements    0
# TotalIntersections       0
# PropertyIntersections    0
# UniqueIntersections      0
# LookupIntersections      0
# PreemptiveIntersections  0
# #######################################################

# %%
steensgaard = pysvf.get_pta()

# %%
type(steensgaard)
# Out:
# pysvf.pysvf.Steensgaard

# %%
tct = pysvf.TCT(steensgaard)

# %%
mhp = pysvf.MHP(tct)

# %%
mhp.analyze()

# %%
svfir.getICFG().dump("icfg.dot")
# Out:
# Writing 'icfg.dot.dot'...

# %%
icfg_node1 = svfir.getICFG().getGNode(11)

# %%
icfg_node1.getId()
# Out:
# 11

# %%
icfg_node2 = svfir.getICFG().getGNode(25)

# %%
icfg_node2.getId()
# Out:
# 25

# %%
mhp.mayHappenInParallelInst(icfg_node1, icfg_node2)
# Out:
# False
